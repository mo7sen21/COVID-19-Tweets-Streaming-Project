# %%
# importing needed libraries for the project

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import re
import json
import tweepy 
import time
import datetime
import seaborn as sns 
import requests
import os
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
# tweepy api credentials  

api_key = '**********************************'
api_secret_key = '**********************************'
bearer_token = '**********************************'
access_token = '**********************************'
access_secret = '**********************************'

# %%
# get the auth for the stream

auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True , wait_on_rate_limit_notify=True)

# %%
# setting the filters 
# you want Dray or dry ?!
# I got the quate ?!

keywords = ['I have high fever', 'I have Dray cough', 'I have sore throat' ,'I have diarrhea',
            'I have difficulty breathing', 'I suffer from loss of taste', 'I suffer from loss of smell',
            'I got the pandemic','I got the quote', 'I got corona virus', 'I got coronavirus',
            'I got covid', 'I got covid19' ,'I suffer from tiredness', 'I have difficulty breathing','I have COVID-19',
           'I suffer from tiredness', 'I suffer from sore throat', 'I have diarrhea', 'I have high fever',
           'I have dry cough']
keywords_2 = ['pandemic', 'fever' , 'dray cough', 'sore throat', 'diarrhea', 'difficulty breathing', 'loss taste',
              'loss smell', 'coronavirus', 'covid19', 'tiredness', 'quarantine', 'immunity', 'Zink', 'severe flu', 'quote',
              'Covid', 'tiredness']
# there are common filters like: 'I suffer from tiredness', 'I have high fever'
# and similar filters : I suffer from sore throat' = 'have' , 'i have dry cough ' = 'dry', 'I have COVID-19' = 'got'
#and a filter that I think belongs to the first: 'I have diarrhea','I have difficulty breathing'
hashtags = ['#COVID19', '#covid', '#corona_virus', '#Stayed_Home', '#immune_system',
            '#flu', '#cold', '#Vitamin_C', '#immunity', '#Vitamin_D', '#Zink', 
            '#Quarantine']

# %% [markdown]
# # Setting a streamer
# ### We have 3 options :
# - filtering with a sampling code, setting streamer to be on and off every 3-5 mins for a period of time
# - getting a sample and filter it with our rules
# - getting a live stream filtered then sample it
#
# ### We can also use api v2 and get a filtered sampled stream, but note:
# - tweepy is not yet ready to work with api 2, and there's not fully actibe library for it , so we will use requests library and some hard coding to set a stream
# - here's the offical statemen on how filtered stream using the sample feature works ;
#
# "Returns a random percent sample of Tweets that match a rule rather than the entire set of Tweets. The percent value must be represented by an integer between 1 and 100 (for example, sample:10 will return a random 10% sample).
# This operator first reduces the scope of the stream to the percentage you specified, then the rule/filter is applied to that sampled subset. In other words, if you are using, for example, sample:10, each Tweet will have a 10% chance of being in the sample.
#
# This operator applies to the entire rule and requires all OR'd terms to be grouped."

# %%
# Setting the first streamer
# get a filtered stream and sample it 

errors = []

class StreamListener(tweepy.StreamListener):
    def __init__(self, limit_tweets):
        self.counter = 0 
        self.out_counter = 0
        self.limit_tweets = limit_tweets 
    def on_data(self, data):
            data_json = json.loads(data)
            try:
                if data_json['in_reply_to_status_id'] != None or data_json['text'][:2] == 'RT':
                    self.out_counter += 1
                else:
                    with open('stream_tweets_json_final.txt' ,'a') as f:
                        json.dump(data_json, f)
                        f.write('\n')
                        self.counter += 1
                        print(self.counter)
                        if self.counter == self.limit_tweets:
                            print('Reached the Targeted Sample')
                            end_time = datetime.datetime.now()
                            print(end_time)
                            print('number of retweets and replies:')
                            print(self.out_counter)
                            return False
            except Exception as e:
                print('Exeption Encountered:')
                print(e)
                return True
    def on_error(self, data):
        if status_code == 420:
            return False
        else:
            error = {'Error' : status_code,
                    'tweet' : data}
            errors.append(error)
            return True
        
#erros_df = pd.DataFrame(errors)

# %%
stream_listener = StreamListener
stream = tweepy.Stream(auth = api.auth, listener=stream_listener(limit_tweets = 116459))
#stream.sample()

# %% [markdown]
# # timing:
# - start :
# - inturruption 1 : 2020-10-16 10:30:30
# - inturruption 2 : 2020-10-16 10:36:33
# - inturruption 3 : 2020-10-16 10:38:43
# - inturruption 4 : 2020-10-16 10:38:43
# - inturruption 5 : 2020-10-16 11:01:09
# - inturruption 6 :2020-10-16 11:33:30
# - Code Update : 2020-10-16 12:39:29 on 27966 tweet
# - 500000 - 27966 - 50922 - 304653
# - end : 50922
# - 304653
# - Ended : 2020-10-18 12:11:55.569297

# %%
now = datetime.datetime.now()
print(now)
stream.filter(track = keywords_2, languages=["en"] , is_async =True)
# Out:
# 2020-10-18 12:05:15.955585
# 114874
# 114875
# 114876
# 114877
# 114878
# 114879
# 114880
# 114881
# 114882
# 114883
# 114884
# 114885
# 114886
# 114887
# 114888
# 114889
# 114890
# 114891
# 114892
# 114893
# 114894
# 114895
# 114896
# 114897
# 114898
# 114899
# 114900
# 114901
# 114902
# 114903
# 114904
# 114905
# 114906
# 114907
# 114908
# 114909
# 114910
# 114911
# 114912
# 114913
# 114914
# 114915
# 114916
# 114917
# 114918
# 114919
# 114920
# 114921
# 114922
# 114923
# 114924
# 114925
# 114926
# 114927
# 114928
# 114929
# 114930
# 114931
# 114932
# 114933
# 114934
# 114935
# 114936
# 114937
# 114938
# 114939
# 114940
# 114941
# 114942
# 114943
# 114944
# 114945
# 114946
# 114947
# 114948
# 114949
# 114950
# 114951
# 114952
# 114953
# 114954
# 114955
# 114956
# 114957
# 114958
# 114959
# 114960
# 114961
# 114962
# 114963
# 114964
# 114965
# 114966
# 114967
# 114968
# 114969
# 114970
# 114971
# 114972
# 114973
# 114974
# 114975
# 114976
# 114977
# 114978
# 114979
# 114980
# ...

# %%
500000 - 27966 - 50922 - 304653- 116459
# Out:
# 0

# %% [markdown]
# - replies and retweets for the sample of 500000 tweets == 635012
